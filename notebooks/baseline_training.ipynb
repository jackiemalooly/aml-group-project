# %%
# !pip install roboflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 1.9 MB/s eta 0:00:005.5 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 10.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 KB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 KB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 22.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 30.2 MB/s eta 0:00:00m eta 0:00:010:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 35.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   WARNING: The script filetype is installed in '/user/HS402/rs02294/.local/bin' which is not on PATH.
# ...

# %%
# !git clone https://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@github.com/jackiemalooly/aml-group-project.git
# Out:
# Cloning into 'aml-group-project'...
# remote: Enumerating objects: 178, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 178 (delta 36), reused 19 (delta 17), pack-reused 105 (from 1)
# Receiving objects: 100% (178/178), 10.28 MiB | 40.47 MiB/s, done.
# Resolving deltas: 100% (68/68), done.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="L8YqMNwoa6LdEvSOs7gJ")
project = rf.workspace("aircraft-detection-tidog").project("aircraft-detection-using-yolo")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Aircraft-Detection-using-Yolo--2 in yolov8:: 1

# %%
# !pwd
# Out:
# /user/HS402/rs02294/AML/aml-group-project

# %%
cd aml-group-project/
# Out:
# [Errno 2] No such file or directory: 'aml-group-project/'
# /user/HS402/rs02294/AML/aml-group-project

# %%
# !pwd
# Out:
# /user/HS402/rs02294/AML/aml-group-project

# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.5/898.5 KB 7.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.8/725.8 KB 10.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.6/290.6 KB 6.3 MB/s eta 0:00:000:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 11.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.5 MB/s eta 0:00:000m eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 339.9/339.9 KB 12.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 KB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 27.8 MB/s eta 0:00:00m eta 0:00:010:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 KB 3.6 MB/s eta 0:00:00
# ...

# %%
# !/bin/bash train.sh
# Out:
# Random seed set to: 42
# ...
# 100%|██████████████████████████████████████| 21.5M/21.5M [00:02<00:00, 10.8MB/s]
# Using YAML file: datasets/data.yaml
# New https://pypi.org/project/ultralytics/8.3.103 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA RTX A4000, 16094MiB)
# ...

# %%
# !/bin/bash train.sh
# Out:
# Random seed set to: 42
# Model loaded from path: best.pt
# Using dataset YAML file: datasets/data.yaml
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA RTX A4000, 16094MiB)
# Model summary (fused): 168 layers, 11,156,931 parameters, 0 gradients, 28.6 GFLOPs
# val: Scanning /user/HS402/rs02294/AML/aml-group-project/datasets/test/labels...
# val: New cache created: /user/HS402/rs02294/AML/aml-group-project/datasets/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2017       3622      0.318      0.253      0.213      0.183
#                    A10         49         76      0.375      0.408      0.407      0.354
#                  A400M         37         59      0.201      0.237       0.22      0.178
#                  AG600         20         21      0.226      0.762      0.486      0.415
#                   AH64         38         52      0.227      0.442        0.2      0.143
# ...

# %%
# !/bin/bash train.sh
# Out:
# Random seed set to: 42
# Using YAML file: datasets/data.yaml
# New https://pypi.org/project/ultralytics/8.3.107 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA RTX A4000, 16094MiB)
# ...

# %%
# !pwd
# Out:
# /user/HS402/rs02294/AML/aml-group-project

# %%
import comet_ml
from comet_ml import Experiment
experiment = Experiment(
    api_key="teVXC7QidGJyaLMo792tbeSRc",
    project_name="yolo8-baseline_augmentation",
    workspace="rishieee",
    auto_metric_logging=True, 
    auto_param_logging=True,
    auto_output_logging="simple",
)
# Out:
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : numerous_seed_9660
# COMET INFO:     url                   : https://www.comet.com/rishieee/yolo8-baseline-augmentation/cb42de60f21b4f36b4ecdd43b2fe1c0f
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# ...

# %%
experiment.end()
# Out:
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : secret_taste_6292
# COMET INFO:     url                   : https://www.comet.com/rishieee/yolo8-baseline-augmentation/82a610c4e7334efb90f21ed3eb545207
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET INFO: Please wait for metadata to finish uploading (timeout is 3600 seconds)
# COMET INFO: Uploading 1 metrics, params and output messages

# %%
# !/bin/bash train.sh
# Out:
# Random seed set to: 42
# Namespace(model_mode='train', model_name='yolov8m.pt', epochs=50, model_task='detect', imgsz=640, dataset_location='datasets', hyp='hyp.no-augmentation.yaml')
# hyp.no-augmentation.yaml
# Using YAML file: datasets/data.yaml
# Using hyperparameter file: hyp.no-augmentation.yaml
# New https://pypi.org/project/ultralytics/8.3.107 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA RTX A4000, 16094MiB)
# ...

# %%
# !/bin/bash val.sh
# Out:
# Random seed set to: 42
# Namespace(model_mode='val', model_name='runs/detect/train11/weights/best.pt', epochs=5, model_task='detect', imgsz=640, dataset_location='datasets', hyp=None, iou=0.6, conf=0.25, save=True, batch=16)
# Using YAML file: datasets/data.yaml
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA RTX A4000, 16094MiB)
# Model summary (fused): 218 layers, 25,886,659 parameters, 0 gradients, 78.9 GFLOPs
# val: Scanning /user/HS402/rs02294/AML/aml-group-project/datasets/valid/labels.ca
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1954       3483      0.488      0.254      0.384      0.348
#                    A10         41         72      0.737      0.194      0.461      0.409
#                  A400M         38         57      0.619      0.228      0.454       0.42
#                  AG600         24         24      0.737      0.583       0.71      0.668
# ...

# %%
# !pwd
# Out:
# /user/HS402/rs02294/AML/aml-group-project

# %%
# !/bin/bash val.sh
# Out:
# Random seed set to: 42
# Namespace(model_mode='val', model_name='runs/detect/train11/weights/best.pt', epochs=5, model_task='detect', imgsz=640, dataset_location='datasets', hyp=None, iou=0.2, conf=0.01, save=True, batch=16)
# Using YAML file: datasets/data.yaml
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA RTX A4000, 16094MiB)
# Model summary (fused): 218 layers, 25,886,659 parameters, 0 gradients, 78.9 GFLOPs
# val: Scanning /user/HS402/rs02294/AML/aml-group-project/datasets/valid/labels.ca
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1954       3483      0.397      0.307      0.346      0.303
#                    A10         41         72      0.468      0.245      0.311      0.261
#                  A400M         38         57      0.515      0.336      0.392      0.328
#                  AG600         24         24      0.572      0.583      0.666      0.617
# ...

# %%
# !/bin/bash test.sh

# %%
ccc
# Out:
# Random seed set to: 42
# Namespace(model_mode='train', model_name='yolov8m.pt', epochs=50, model_task='detect', imgsz=640, dataset_location='datasets', hyp='hyp.scratch-high.yaml', iou=0.6, conf=0.25, save=True, batch=32)
# hyp.scratch-high.yaml
# Using YAML file: datasets/data.yaml
# Using hyperparameter file: hyp.scratch-high.yaml
# New https://pypi.org/project/ultralytics/8.3.108 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA RTX A4000, 16094MiB)
# ...
